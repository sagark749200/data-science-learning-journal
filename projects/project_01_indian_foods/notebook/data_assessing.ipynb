# %%
import numpy as numpy
import pandas as pd

# %%
df = pd.read_csv("../data/indian_food.csv")

# %%
df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
df.sample(5)
# Out:
#                name                                        ingredients  \
# 126  Bisi bele bath  Split pigeon peas, chana dal, urad dal, green ...
# 164            Upma   Chana dal, urad dal, ginger, curry leaves, sugar
# 110        Panjeeri  Whole wheat flour, musk melon seeds, poppy see...
# 192         Khandvi  Green chili paste, white sesame seeds, gram fl...
# 111           Papad       Urad dal, sev, lemon juice, chopped tomatoes
#
#            diet  prep_time  cook_time flavor_profile       course  \
# 126  vegetarian         30         45          spicy  main course
# 164  vegetarian         10         20          spicy        snack
# 110  vegetarian         10         25          sweet      dessert
# 192  vegetarian         20         45          spicy        snack
# 111  vegetarian          5          5          spicy        snack
#
#              state region
# 126      Karnataka  South
# 164             -1     -1
# 110  Uttar Pradesh    NaN
# 192        Gujarat   West
# ...

# %%
df.shape
# Out:
# (255, 9)

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    object
#  1   ingredients     255 non-null    object
#  2   diet            255 non-null    object
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  255 non-null    object
#  6   course          255 non-null    object
#  7   state           255 non-null    object
#  8   region          254 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 18.1+ KB

# %%
df.describe()

#min = -1 assign to NaN
# Out:
#         prep_time   cook_time
# count  255.000000  255.000000
# mean    31.105882   34.529412
# std     72.554409   48.265650
# min     -1.000000   -1.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %%
df.isnull().sum()

#in region there is 1 missing value
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# dtype: int64

# %%
(df == -1).sum()

# prep time has 30 nan values
# cook time has 28 nan values
# Out:
# name               0
# ingredients        0
# diet               0
# prep_time         30
# cook_time         28
# flavor_profile     0
# course             0
# state              0
# region             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# name              255
# ingredients       252
# diet                2
# prep_time          22
# cook_time          19
# flavor_profile      5
# course              4
# state              25
# region              7
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist(figsize=(10,8),bins=30, color='green')
plt.suptitle('overall numeric ditribution')
plt.show()

# %%
df.boxplot(figsize=(10,5))
plt.title('overall numeric ditribution')
plt.show()

# %%
df[df['prep_time'] > 200]

# puttu prep time wrong range (240-360)
# tandoori fish tikka prep time wrong range (60-120)
# Out:
#                     name                                        ingredients  \
# 29             Misti doi                                      Milk, jaggery
# 48              Poornalu                                 Chana dal, jaggery
# 66        Chak Hao Kheer                        Rice, milk, sugar, cardamom
# 114          Pindi chana   Fennel, tea bags, tomato, kasuri methi, cinnamon
# 122     Tandoori Chicken  Greek yogurt, garam masala, kasuri methi, mari...
# 123  Tandoori Fish Tikka  Chickpea flour, biryani masala powder, yogurt,...
# 128                 Dosa  Chana dal, urad dal, whole urad dal, blend ric...
# 130                 Idli  Split urad dal, urad dal, idli rice, thick poh...
# 144          Masala Dosa  Chana dal, urad dal, potatoes, idli rice, thic...
# 155                Puttu            Brown rice flour, sugar, grated coconut
#
#                diet  prep_time  cook_time flavor_profile       course  \
# ...

# %% [markdown]
# ** Column Wise Analysis **

# %%
df.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='object')

# %% [markdown]
# 1. Name

# %%
df['name'].isnull().sum()
df['name'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['name'].nunique()
# Out:
# 255

# %%
(df['name'] == -1).sum()
# Out:
# np.int64(0)

# %%
df[df['name'].str.strip() == '']
# Out:
# Empty DataFrame
# Columns: [name, ingredients, diet, prep_time, cook_time, flavor_profile, course, state, region]
# Index: []

# %%
df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
df['name'].apply(lambda X: len(str(X)))
# Out:
# 0      10
# 1       6
# 2      14
# 3       6
# 4      11
#        ..
# 250     9
# 251     7
# 252     6
# 253     9
# 254     6
# Name: name, Length: 255, dtype: int64

# %% [markdown]
# 2. ingredients

# %%
df['ingredients'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df['ingredients'] == -1).sum()
df[df['ingredients'].str.strip() == '']
# Out:
# Empty DataFrame
# Columns: [name, ingredients, diet, prep_time, cook_time, flavor_profile, course, state, region]
# Index: []

# %%
df['ingredients'].nunique()
# Out:
# 252

# %%
df['ingredients'].duplicated().sum()
# Out:
# np.int64(3)

# %%
df[df['ingredients'].duplicated()]

# these dishes have same ingredients
# Out:
#          name                                        ingredients        diet  \
# 10      Laddu                            Gram flour, ghee, sugar  vegetarian
# 25   Ledikeni                                Chhena, sugar, ghee  vegetarian
# 199     Patra  Arbi ke patte, sesame seeds, gur, bengal gram ...  vegetarian
#
#      prep_time  cook_time flavor_profile   course        state region
# 10          10         40          sweet  dessert           -1     -1
# 25          45         45          sweet  dessert  West Bengal   East
# 199         10         40          spicy    snack      Gujarat   West

# %%
df.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='object')

# %% [markdown]
# 3. diet

# %%
df['diet'].value_counts()
# Out:
# diet
# vegetarian        226
# non vegetarian     29
# Name: count, dtype: int64

# %%
df['diet'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5))
plt.show()

# %% [markdown]
# 4. prep_time

# %%
df['prep_time'].head()
df['prep_time'].describe()
# min value is -1 which is invalid
# Out:
# count    255.000000
# mean      31.105882
# std       72.554409
# min       -1.000000
# 25%       10.000000
# 50%       10.000000
# 75%       20.000000
# max      500.000000
# Name: prep_time, dtype: float64

# %%
df['prep_time'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df['prep_time'] == -1).sum()

# total 30 invalid values
# Out:
# np.int64(30)

# %%
(df['prep_time'] == 0).sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(x=df['prep_time'])
plt.title("prep time boxplot")
plt.show()

# %%
df[df['prep_time'] > 200]

# puttu prep time wrong range (240-360)
# tandoori fish tikka prep time wrong range (60-120)
# Out:
#                     name                                        ingredients  \
# 29             Misti doi                                      Milk, jaggery
# 48              Poornalu                                 Chana dal, jaggery
# 66        Chak Hao Kheer                        Rice, milk, sugar, cardamom
# 114          Pindi chana   Fennel, tea bags, tomato, kasuri methi, cinnamon
# 122     Tandoori Chicken  Greek yogurt, garam masala, kasuri methi, mari...
# 123  Tandoori Fish Tikka  Chickpea flour, biryani masala powder, yogurt,...
# 128                 Dosa  Chana dal, urad dal, whole urad dal, blend ric...
# 130                 Idli  Split urad dal, urad dal, idli rice, thick poh...
# 144          Masala Dosa  Chana dal, urad dal, potatoes, idli rice, thic...
# 155                Puttu            Brown rice flour, sugar, grated coconut
#
#                diet  prep_time  cook_time flavor_profile       course  \
# ...

# %%
df['prep_time'].plot(kind='hist', bins=30, figsize=(8,4), color='orange')
plt.xlabel('minutes')
plt.ylabel('dishes')
plt.show()

# %%
df['prep_time'].skew()

#highly skewed
# Out:
# np.float64(4.636300925063016)

# %% [markdown]
# 5. cook_time

# %%
df['cook_time'].head()
df['cook_time'].describe()
# min value is -1 which is invalid
# Out:
# count    255.000000
# mean      34.529412
# std       48.265650
# min       -1.000000
# 25%       20.000000
# 50%       30.000000
# 75%       40.000000
# max      720.000000
# Name: cook_time, dtype: float64

# %%
df['cook_time'].isnull().sum()
(df['cook_time'] == -1).sum()

# total 28 invalid values
# Out:
# np.int64(28)

# %%
sns.boxplot(x=df['cook_time'])
plt.title("cook time boxplot")
plt.show()

# outlier of 700 mins cook time

# %%
df[df['cook_time'] > 200]

# wrong cook time, shrikhand takes only prep time 10-15 mins
# cook time for shrikhand is 0
# Out:
#          name                     ingredients        diet  prep_time  \
# 62  Shrikhand  Curd, sugar, saffron, cardamom  vegetarian         10
#
#     cook_time flavor_profile   course        state region
# 62        720          sweet  dessert  Maharashtra   West

# %%
df['cook_time'].plot(kind='hist', bins=30, figsize=(8,4), color='orange')
plt.xlabel('minutes')
plt.ylabel('dishes')
plt.show()

# %%
df[df['cook_time'] < 10]
# Out:
#                name                                        ingredients  \
# 11            Lassi                          Yogurt, milk, nuts, sugar
# 65      Pork Bharta   Boiled pork, onions, chillies, ginger and garlic
# 109       Pani puri      Kala chana, mashed potato, boondi, sev, lemon
# 111           Papad       Urad dal, sev, lemon juice, chopped tomatoes
# 132  Kaara kozhambu  Sesame oil, drumstick, tamarind paste, sambar ...
# 134  Keerai masiyal  Urad dal, curry leaves, sugar, mustard seeds, ...
# 147         Papadum               Lentils, black pepper, vegetable oil
# 148      Paravannam                           Raw rice,  jaggery, milk
# 152         Poriyal       Chana dal, urad dal, beans, coconut, mustard
# 167     Kolim Jawla  Baingan, fish, coconut oil, fresh coconut, ginger
# 172      Bombil fry  Bombay duck, malvani masala, rice flour, bomba...
# 185        Ghooghra            Dry fruits, semolina, all purpose flour
# ...

# %%
df['cook_time'].skew()

#highly skewed
# Out:
# np.float64(11.433429571676461)

# %%
df.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='object')

# %% [markdown]
# 6. flavour

# %%
df.rename(columns={'flavor_profile':'flavour'}, inplace=True)

# %%
df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavour   course        state region
# 0  vegetarian         45         25   sweet  dessert  West Bengal   East
# 1  vegetarian         80         30   sweet  dessert    Rajasthan   West
# 2  vegetarian         15         60   sweet  dessert       Punjab  North
# 3  vegetarian         15         30   sweet  dessert    Rajasthan   West
# 4  vegetarian         15         40   sweet  dessert  West Bengal   East

# %%
df['flavour'].value_counts()
# Out:
# flavour
# spicy     133
# sweet      88
# -1         29
# bitter      4
# sour        1
# Name: count, dtype: int64

# %%
df[df['flavour'] == 'bitter']
# Out:
#               name                                        ingredients  \
# 71      Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 93   Karela bharta  Bitter gourd, fennel, garam masala powder, chi...
# 196  Methi na Gota  Rava, gram flour, lemon juice, turmeric, fenug...
# 198        Muthiya  Bottle gourd, whole wheat flour, rava, sesame ...
#
#            diet  prep_time  cook_time flavour       course    state region
# 71   vegetarian         10         40  bitter  main course   Punjab  North
# 93   vegetarian         20         50  bitter  main course   Punjab  North
# 196  vegetarian         15         30  bitter  main course  Gujarat   West
# 198  vegetarian         15         30  bitter        snack  Gujarat   West

# %%
df[df['flavour'] == 'sour']

# 'keri no ras' is is a sweet dish
# Out:
#             name   ingredients        diet  prep_time  cook_time flavour  \
# 190  Keri no ras  Mango, sugar  vegetarian         10         10    sour
#
#           course    state region
# 190  main course  Gujarat   West

# %%
(df['flavour'] == '-1').sum()

#flavour column has string -1 for 29 missing values
# Out:
# np.int64(29)

# %%
df['flavour'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5))
plt.show()

# %%
df['flavour'].value_counts().plot(kind='bar', color='lightblue', figsize=(7,4))
plt.xlabel("Flavor Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# 7. course -> dish_type

# %%
df.rename(columns={'course':'dish_type'}, inplace=True)

# %%
df['dish_type'].value_counts()
# Out:
# dish_type
# main course    129
# dessert         85
# snack           39
# starter          2
# Name: count, dtype: int64

# %%
df['dish_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['dish_type'] == 'starter']
# Out:
#                     name                                        ingredients  \
# 81         Chicken Tikka  Chicken, whole wheat bread, rice flour, garam ...
# 123  Tandoori Fish Tikka  Chickpea flour, biryani masala powder, yogurt,...
#
#                diet  prep_time  cook_time flavour dish_type   state region
# 81   non vegetarian        120         45   spicy   starter  Punjab  North
# 123  non vegetarian        240         30   spicy   starter  Punjab  North

# %%
df[df['dish_type'] == 'snack']
# Out:
#                   name                                        ingredients  \
# 88                Poha  Beaten rice flakes, potato, curry leaves, gree...
# 89                Fara  Chana dal, whole wheat flour, arhar dal, white...
# 90             Kachori  Moong dal, rava, garam masala, dough, fennel s...
# 109          Pani puri      Kala chana, mashed potato, boondi, sev, lemon
# 111              Papad       Urad dal, sev, lemon juice, chopped tomatoes
# 117             Samosa  Potatoes, green peas, garam masala, ginger, dough
# 124               Attu  Whole wheat flour, arhar dal, ginger, kala jee...
# 128               Dosa  Chana dal, urad dal, whole urad dal, blend ric...
# 129           Idiappam              Rice flour, hot water, grated coconut
# 130               Idli  Split urad dal, urad dal, idli rice, thick poh...
# 131              Kanji     Carrot, yellow mustard, red chilli, black salt
# 144        Masala Dosa  Chana dal, urad dal, potatoes, idli rice, thic...
# ...

# %%
# 'snack' and 'starter' are same dish types. We can merge them.

# %%
df['dish_type'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5))
plt.show()

# %%
df['dish_type'].value_counts().plot(kind='bar', color='green', figsize=(7,4))
plt.xlabel("Dish Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# 8. state

# %%
df['state'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['state'].value_counts()

# will tackle -1 later
# Out:
# state
# Gujarat            35
# Punjab             32
# Maharashtra        30
# -1                 24
# West Bengal        24
# Assam              21
# Tamil Nadu         20
# Andhra Pradesh     10
# Uttar Pradesh       9
# Kerala              8
# Odisha              7
# Karnataka           6
# Rajasthan           6
# Telangana           5
# Bihar               3
# Goa                 3
# Madhya Pradesh      2
# Jammu & Kashmir     2
# Manipur             2
# Uttarakhand         1
# Tripura             1
# NCT of Delhi        1
# Nagaland            1
# Haryana             1
# Chhattisgarh        1
# Name: count, dtype: int64

# %%
df['state'].nunique()
# Out:
# 25

# %%
df['state'].value_counts().head(10)
# Out:
# state
# Gujarat           35
# Punjab            32
# Maharashtra       30
# -1                24
# West Bengal       24
# Assam             21
# Tamil Nadu        20
# Andhra Pradesh    10
# Uttar Pradesh      9
# Kerala             8
# Name: count, dtype: int64

# %%
df['state'].value_counts().head(10).plot(kind='bar', color='purple', figsize=(8,4))
plt.xlabel("State")
plt.ylabel("total dishes")
plt.show()

# %%
df[df['state'].str.strip() == '']
# Out:
# Empty DataFrame
# Columns: [name, ingredients, diet, prep_time, cook_time, flavour, dish_type, state, region]
# Index: []

# %%
df.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time', 'flavour',
#        'dish_type', 'state', 'region'],
#       dtype='object')

# %% [markdown]
# 9. region

# %%
df['region'].value_counts()
# Out:
# region
# West          74
# South         59
# North         49
# East          31
# North East    25
# -1            13
# Central        3
# Name: count, dtype: int64

# %%
df['region'].isnull().sum()

# 1 missing value
# Out:
# np.int64(1)

# %%
df[df['region'].str.strip() == '']
# Out:
# Empty DataFrame
# Columns: [name, ingredients, diet, prep_time, cook_time, flavour, dish_type, state, region]
# Index: []

# %%
df['region'].value_counts().plot(kind='bar', color='lightgreen', figsize=(7,4))
plt.xlabel("Region")
plt.ylabel("Dish Count")
plt.show()
